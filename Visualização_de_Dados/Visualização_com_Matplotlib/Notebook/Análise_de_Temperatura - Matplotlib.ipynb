# %% [markdown]
# <a href="https://colab.research.google.com/github/KZoc/Formacao_1_Data_Science/blob/main/Visualiza%C3%A7%C3%A3o_de_Dados/Visualiza%C3%A7%C3%A3o_com_Matplotlib/Notebook/An%C3%A1lise_de_Temperatura%20-%20Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # - Importando Bibliotecas e Dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
URL = 'https://raw.githubusercontent.com/KZoc/Formacao_1_Data_Science/main/Visualiza%C3%A7%C3%A3o_de_Dados/Visualiza%C3%A7%C3%A3o_com_Matplotlib/Dados/monitoramento_tempo.csv'
df = pd.read_csv(URL)

# %%
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
plt.figure(figsize=(15,8))
plt.plot(df['data'], df['temperatura'])

# %%
plt.figure(figsize=(15,8))
plt.plot(df['data'], df['temperatura'])
plt.title('Temperatura no Tempo', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Temperatura no Tempo')

# %% [markdown]
# ## Avançando na Customização da Visualização

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df['data'], df['temperatura'], color='green')

eixo.set_title('Temperatura no Momento', fontsize=30)
eixo.set_ylabel('Temperatura (kelvin)', fontsize=22)
eixo.set_xlabel('Data', fontsize=22)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=18)

# %%
import datetime

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura em 2014', fontsize=30)
eixo.set_ylabel('Temperatura (kelvin)', fontsize=22)
eixo.set_xlabel('Data', fontsize=22)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=18)
eixo.grid(True)


eixo2.plot(df['data'], df['temperatura'], color='b')
eixo2.set_title('Temperatura no Momento', fontsize=15)
eixo2.set_ylabel('Temperatura (kelvin)', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.legend(['Temperatura'], loc = 'best', fontsize=8)
eixo2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_title('Temperatura em 2014', fontsize=30)
eixo.set_ylabel('Temperatura (kelvin)', fontsize=22)
eixo.set_xlabel('Data', fontsize=22)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=18)
eixo.grid(True)


eixo2.plot(df['data'], df['temperatura'], color='b')
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura no Momento', fontsize=15)
eixo2.set_ylabel('Temperatura (kelvin)', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.legend(['Temperatura'], loc = 'best', fontsize=8)
eixo2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.67, 0.66, 0.3, 0.3])

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura de Maio de 2014', fontsize=30)
eixo.set_ylabel('Temperatura (kelvin)', fontsize=22)
eixo.set_xlabel('Data', fontsize=22)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=18)
eixo.grid(True)


eixo2.plot(df['data'], df['temperatura'], color='b')
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize=15)
eixo2.set_ylabel('Temperatura (kelvin)', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.legend(['Temperatura'], loc = 'best', fontsize=8)
eixo2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.67, 0.66, 0.3, 0.3])

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura de Maio de 2014', fontsize=30)
eixo.set_ylabel('Temperatura (kelvin)', fontsize=22)
eixo.set_xlabel('Data', fontsize=22)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize=18)
eixo.grid(True)

azul_esquerda = df['data'] < datetime.datetime(2014, 5, 1)
azul_direita = df['data'] > datetime.datetime(2014, 6, 1)

eixo2.plot(df['data'], df['temperatura'], color='g')
eixo2.plot(df[azul_esquerda]['data'], df[azul_esquerda]['temperatura'], color = 'b')
eixo2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color = 'b')
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize=15)
eixo2.set_ylabel('Temperatura (kelvin)', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.legend(['Temperatura'], loc = 'best', fontsize=8)
eixo2.grid(True)

# %% [markdown]
# ## Gráfico com Linhas de Temp. Máx e Min

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color = 'g')
eixo.set_title('Temperatura no Período', fontsize=30, pad=20)
eixo.set_xlabel('Data', fontsize=25)
eixo.set_ylabel('Temperatua (kelvin)', fontsize=25)
eixo.legend('Temperatura', loc = 'lower right', fontsize=15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()] #Pega o a data com maior temperatura
y1 = max(df.temperatura)

eixo.annotate('Máximo', xy=(x1,y1), fontsize=20)

eixo.axhline(max(df['temperatura']), color = 'k', linestyle='--')
eixo.axhline(min(df['temperatura']), color = 'k', linestyle='--')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color = 'g')
eixo.set_title('Temperatura no Período', fontsize=30, pad=20)
eixo.set_xlabel('Data', fontsize=25)
eixo.set_ylabel('Temperatua (kelvin)', fontsize=25)
eixo.legend('Temperatura', loc = 'lower right', fontsize=15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()] #Pega o a data com maior temperatura
y1 = max(df.temperatura)

x2 = df['data'][df['temperatura'].idxmax() - 7000] #Pega o a data com maior temperatura
y2 = max(df.temperatura) - 5

eixo.annotate('Máximo', xy=(x1,y1), fontsize=20,
             xytext=(x2,y2), arrowprops=dict(facecolor='k'))

eixo.axhline(max(df['temperatura']), color = 'k', linestyle='--')
eixo.axhline(min(df['temperatura']), color = 'k', linestyle='--')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df.data, df.temperatura, color = 'g')
eixo.set_title('Temperatura no Período', fontsize=30, pad=20)
eixo.set_xlabel('Data', fontsize=25)
eixo.set_ylabel('Temperatua (kelvin)', fontsize=25)
eixo.legend('Temperatura', loc = 'lower right', fontsize=15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()] #Pega o a data com maior temperatura
y1 = max(df.temperatura)

x2 = df['data'][df['temperatura'].idxmax() - 7000] #Pega o a data com maior temperatura
y2 = max(df.temperatura) - 5

eixo.annotate('Máximo', xy=(x1,y1), fontsize=20,
             xytext=(x2,y2), arrowprops=dict(facecolor='k'))

x1 = df['data'][df['temperatura'].idxmin()] #Pega o a data com menor temperatura
y1 = min(df.temperatura)

x2 = df['data'][df['temperatura'].idxmin() - 7000] #Pega o a data com menor temperatura
y2 = min(df.temperatura) + 4

eixo.annotate('Mínimo', xy=(x1,y1), fontsize=20,
             xytext=(x2,y2), arrowprops=dict(facecolor='k'))

eixo.axhline(max(df['temperatura']), color = 'k', linestyle='--')
eixo.axhline(min(df['temperatura']), color = 'k', linestyle='--')

# %% [markdown]
# ## Criando um gráfico para ver a Média de Temperatura nos dias da Semana

# %%
temperatura_dia_semana = df.groupby('dia_da_semana')['temperatura'].mean()
temperatura_dia_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Quarta     284.998290
# Quinta     285.000643
# Segunda    284.985382
# Sexta      285.060886
# Sábado     285.003316
# Terça      284.892811
# Name: temperatura, dtype: float64

# %%
nome_dias = ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado']
temperatura_dia_semana = temperatura_dia_semana[nome_dias]
temperatura_dia_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_dia_semana))

eixo.bar(indice, temperatura_dia_semana)
eixo.set_title('Média de Temperatura nos dias da Semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da Semana', fontsize=15)
eixo.set_ylabel('Temperatura Média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_dia_semana))
cores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_dia_semana, color=cores, edgecolor='k')

eixo.set_title('Média de Temperatura nos dias da Semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da Semana', fontsize=15)
eixo.set_ylabel('Temperatura Média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir = [0.1,0,0,0,0,0.1,0.1]

eixo.pie(temperatura_dia_semana, labels=temperatura_dia_semana.index,
        autopct='%.1f%%', explode=explodir, shadow=True)
eixo.set_title('Média de Temperatura nos dias da Semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Média de Temperatura nos dias da Semana')
